# %%
from PIL import Image, ImageDraw,ImageFont
import cv2 
import numpy as np
import time


image1 = Image.open(r'E:\GOKUL\amul.jpg')
font_type= ImageFont.truetype('arial.ttf', 100)
draw = ImageDraw.Draw(image1)
draw.text(xy=(50,50),text="1",fill=(0,0,0),font=font_type)
image1.save(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT1.jpg")




image2 = Image.open(r'E:\GOKUL\gokul.jpg')
font_type= ImageFont.truetype('arial.ttf', 50)
draw = ImageDraw.Draw(image2)
draw.text(xy=(20,40),text="2",fill=(0,0,0),font=font_type)
image2.save(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT2.jpg")


image3 = Image.open(r'E:\GOKUL\warna.jpg')
font_type= ImageFont.truetype('arial.ttf', 50)
draw = ImageDraw.Draw(image3)
draw.text(xy=(50,20),text="3",fill=(0,0,0),font=font_type)
image3.save(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT3.jpg")



image4 = Image.open(r'E:\GOKUL\nandini.jpg')
font_type= ImageFont.truetype('arial.ttf', 100)
draw = ImageDraw.Draw(image4)
draw.text(xy=(50,50),text="4",fill=(0,0,0),font=font_type)
image4.save(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT4.jpg")

image1=cv2.imread(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT1.jpg")
image2=cv2.imread(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT2.jpg")
image3=cv2.imread(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT3.jpg")
image4=cv2.imread(r"C:\Users\Snehal\Desktop\TEJAS\imges\EDIT4.jpg")

image1=cv2.resize(image1,(300,300))
image2=cv2.resize(image2,(300,300))
image3=cv2.resize(image3,(300,300))
image4=cv2.resize(image4,(300,300))

Horizontal1=np.hstack([image1,image2])
Horizontal2=np.hstack([image3,image4])

Vertical_attachment=np.vstack([Horizontal1,Horizontal2])


cv2.imshow("Final Collage",Vertical_attachment)
cv2.waitKey(0)
cv2.destroyAllWindows()
